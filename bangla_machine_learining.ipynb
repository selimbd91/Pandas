# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
list(df.columns)
# Out:
# ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']

# %%
df2 = df[df["sex"].isin(["Male"])]
df2
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
a = list([1,2, 3])
a
# Out:
# [1, 2, 3]

# %%
b = list([4,5,6])
p = list([9,8,7])
c = np.dstack([a, b])
e = np.stack([a, b, p], axis= 0)
e
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [9, 8, 7]])

# %%
c[0]
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
c[0]
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
d = pd.DataFrame(e)
d
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  9  8  7

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Marketing Raw Data.csv")
df.head()
# Out:
#          Date  Week  Week_ID  Month  Month_ID  Year   Day_Name  Visitors  \
# 0  09/11/2020    46       34     11        11  2020     Monday       707
# 1  10/11/2020    46       34     11        11  2020    Tuesday      1455
# 2  11/11/2020    46       34     11        11  2020  Wednesday      1520
# 3  12/11/2020    46       34     11        11  2020   Thursday      1726
# 4  13/11/2020    46       34     11        11  2020     Friday      2134
#
#    Revenue  Marketing Spend           Promo
# 0      465          651.375        No Promo
# 1    10386         1298.250   Promotion Red
# 2    12475         1559.375  Promotion Blue
# 3    11712         1801.750        No Promo
# 4    10000         2614.500        No Promo

# %%
df.dtypes
# Out:
# Date                object
# Week                 int64
# Week_ID              int64
# Month                int64
# Month_ID             int64
# Year                 int64
# Day_Name            object
# Visitors             int64
# Revenue              int64
# Marketing Spend    float64
# Promo               object
# dtype: object

# %%
ax = sns.lineplot(x= "Week_ID", y= "Revenue", data= df, ci=False)
ax.set_title("mera jan hai to")
plt.show()

# %%
#sns.set(rc={"figure.figsize": [12,10]})
sns.lineplot(x= "Month_ID", y= "Revenue", data= df, hue= "Promo", ci= False, style= "Promo", markers= True)
plt.show()

# %%
sns.barplot(x= "Month_ID", y= "Revenue", data= df, ci= False, hue= "Promo")

# %%
xx = df["Revenue"].values
mean= df["Revenue"].mean()
sns.distplot(xx, color= "blue")
plt.axvline(mean, 0, 1, color= "red")

# %%
 xx.shape
# Out:
# (182,)

# %%
names = ["tickers", 'eps', 'revenue','price', 'people']
stock_df = pd.read_excel("stock_data.xlsx", na_values=["n.a.", '64.0',87.0])
stock_df
# Out:
#   tickers            eps  revenue   price         people
# 0   GOOGL          27.82       87   845.0     larry page
# 1     WMT           4.61      484    65.0            NaN
# 2    MSFT             -1       85     NaN     bill gates
# 3    RIL   not available       50  1023.0  mukesh ambani
# 4    TATA            5.6       -1     NaN     ratan tata

# %%
df = pd.read_excel("stock_data.xlsx","Sheet1")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available      120  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
def call_people(cell):
    if cell == '87':
        return "selim"
    return cell
dff = pd.read_csv("stock_data.csv", na_values=[-1, '50'])
dff
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82     87.0   845     larry page
# 1     WMT           4.61    484.0    65           n.a.
# 2    MSFT            NaN     85.0    64     bill gates
# 3    RIL   not available      NaN  1023  mukesh ambani
# 4    TATA            5.6      NaN  n.a.     ratan tata

# %%
dff.to_excel("amader_data2.xlsx",columns= ["eps", "revenue"], index= False, header= True)

# %%
df = pd.read_csv("stock_data.csv",  na_values={
        'eps': ['not available'],
        'revenue': [-1],
        'people': ['not available','n.a.']
    })
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
df_weather = pd.read_csv("nyc_weather.csv")
df_weather
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df_tips = pd.read_csv("tips.csv")
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
with pd.ExcelWriter("weather and tips.xlsx") as writer:
    df_weather.to_excel(writer, sheet_name= "weather", index= False)
    df_tips.to_excel(writer, sheet_name= "tips", index= False)

# %%
df = pd.read_csv("weather_data.csv" )
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df['day'] = pd.to_datetime(df['day'])
df.set_index("day",inplace= True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
type(df['day'])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
new_df = df.fillna( method= "ffill")
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         32.0        9.0   Sunny
# 2 2017-01-05         28.0        9.0    Snow
# 3 2017-01-06         28.0        7.0    Snow
# 4 2017-01-07         32.0        7.0    Rain
# 5 2017-01-08         32.0        7.0   Sunny
# 6 2017-01-09         32.0        7.0   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna({'temperature': df["temperature"].mean(),
                   'windspeed': 100,
                   'event':'no event' })
new_df
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01         32.0        6.0      Rain
# 1 2017-01-04         33.2        9.0     Sunny
# 2 2017-01-05         28.0      100.0      Snow
# 3 2017-01-06         33.2        7.0  no event
# 4 2017-01-07         32.0      100.0      Rain
# 5 2017-01-08         33.2      100.0     Sunny
# 6 2017-01-09         33.2      100.0  no event
# 7 2017-01-10         34.0        8.0    Cloudy
# 8 2017-01-11         40.0       12.0     Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#new_df = df.interpolate(method= "time" )
#new_df = new_df.fillna(method="ffill")
dt = pd.date_range("2017-01-01", "2017-01-11")
idx = pd.DatetimeIndex(dt)
new_df = df.reindex(idx)
new_df
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df = pd.read_csv("weather_data.csv")
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df2 = df.fillna(method="ffill")
df2
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         32.0        9.0   Sunny
# 2   1/5/2017         28.0        9.0    Snow
# 3   1/6/2017         28.0        7.0    Snow
# 4   1/7/2017         32.0        7.0    Rain
# 5   1/8/2017         32.0        7.0   Sunny
# 6   1/9/2017         32.0        7.0   Sunny
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df = pd.read_csv("weather_data2.csv")
df
# Out:
#         day temperature windspeed  event
# 0  1/1/2017         32F      6mph   Rain
# 1  1/2/2017      -99999         7  Sunny
# 2  1/3/2017          28    -99999   Snow
# 3  1/4/2017      -99999         7      0
# 4  1/5/2017        32 C    -99999   Rain
# 5  1/6/2017          31     2 mph  Sunny
# 6  1/6/2017          34         5      0

# %%
df.dtypes
# Out:
# day            object
# temperature    object
# windspeed      object
# event          object
# dtype: object

# %%
df = df.replace(-99999, df["temperature"].max())
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           34          7  Sunny
# 2  1/3/2017           28         34   Snow
# 3  1/4/2017           34          7      0
# 4  1/5/2017           32         34   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
df = df.replace({
    "temperature": -99999,
    "windspeed" : -99999,
    "event" : "0"
}, np.nan)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
dff = df.replace({
    "temperature" : '[A-Za-z]',
    "windspeed" : '[A-za-z]' 
}, '', regex = True)

dff
# Out:
#         day temperature windspeed  event
# 0  1/1/2017          32         6   Rain
# 1  1/2/2017      -99999         7  Sunny
# 2  1/3/2017          28    -99999   Snow
# 3  1/4/2017      -99999         7      0
# 4  1/5/2017         32     -99999   Rain
# 5  1/6/2017          31        2   Sunny
# 6  1/6/2017          34         5      0

# %%
dff.dtypes
# Out:
# day            object
# temperature    object
# windspeed      object
# event          object
# dtype: object

# %%
dff["temperature"] = dff["temperature"].astype('float64')
dff["windspeed"] = pd.to_numeric(dff['windspeed'])
dff
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0          6   Rain
# 1  1/2/2017     -99999.0          7  Sunny
# 2  1/3/2017         28.0     -99999   Snow
# 3  1/4/2017     -99999.0          7      0
# 4  1/5/2017         32.0     -99999   Rain
# 5  1/6/2017         31.0          2  Sunny
# 6  1/6/2017         34.0          5      0

# %%
dff.dtypes
# Out:
# day             object
# temperature    float64
# windspeed        int64
# event           object
# dtype: object

# %%
df_stu = pd.DataFrame({
    'Name': ["rahim", "karim", "sakib"],
    "Score": ["good", 'better', 'best'],
    'Age': [11, 12, 14]
})
df_stu
# Out:
#     Name   Score  Age
# 0  rahim    good   11
# 1  karim  better   12
# 2  sakib    best   14

# %%
df_stu.replace(['best', 'good', 'better'], [1,3,2], inplace= True)
df_stu
# Out:
#     Name  Score  Age
# 0  rahim      3   11
# 1  karim      2   12
# 2  sakib      1   14

# %%
df = pd.read_csv("weather_by_cities.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     Dhaka           42         10  Cloudy

# %%
gr = df.groupby("city")
gr

# %%
gr.get_group('Dhaka')
# Out:
#          day   city  temperature  windspeed   event
# 11  1/4/2017  Dhaka           42         10  Cloudy

# %%
dff = gr.get_group("mumbai")
dff["temperature"].max()
# Out:
# 92

# %%
gr.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
for city, city_df in gr:
    print(city)
    print(city_df)
# Out:
# Dhaka
#          day   city  temperature  windspeed   event
# 11  1/4/2017  Dhaka           42         10  Cloudy
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy

# %%
ddff = gr.get_group("paris")
ddff.reset_index(inplace= True)
ddff
# Out:
#    index       day   city  temperature  windspeed   event
# 0      8  1/1/2017  paris           45         20   Sunny
# 1      9  1/2/2017  paris           50         13  Cloudy
# 2     10  1/3/2017  paris           54          8  Cloudy

# %%
df = pd.read_csv("weather_by_cities.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     Dhaka           42         10  Cloudy

# %%
group = df.groupby('event')

for event, event_df in group:
    print(event)
    print(event_df)
# Out:
# Cloudy
#          day   city  temperature  windspeed   event
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  Dhaka           42         10  Cloudy
# Fog
#         day    city  temperature  windspeed event
# 5  1/2/2017  mumbai           85         12   Fog
# 6  1/3/2017  mumbai           87         15   Fog
# Rain
#         day      city  temperature  windspeed event
# 0  1/1/2017  new york           32          6  Rain
# 7  1/4/2017    mumbai           92          5  Rain
# Snow
#         day      city  temperature  windspeed event
# 2  1/3/2017  new york           28         12  Snow
# Sunny
#         day      city  temperature  windspeed  event
# 1  1/2/2017  new york           36          7  Sunny
# 3  1/4/2017  new york           33          7  Sunny
# 4  1/1/2017    mumbai           90          5  Sunny
# 8  1/1/2017     paris           45         20  Sunny

# %%
df1 = group.get_group("Cloudy")
df1.reset_index(inplace=True)
df1
# Out:
#    index       day   city  temperature  windspeed   event
# 0      9  1/2/2017  paris           50         13  Cloudy
# 1     10  1/3/2017  paris           54          8  Cloudy
# 2     11  1/4/2017  Dhaka           42         10  Cloudy

# %%
df2 = group.get_group("Sunny")
df2 = df2.reset_index()
df2
# Out:
#    index       day      city  temperature  windspeed  event
# 0      1  1/2/2017  new york           36          7  Sunny
# 1      3  1/4/2017  new york           33          7  Sunny
# 2      4  1/1/2017    mumbai           90          5  Sunny
# 3      8  1/1/2017     paris           45         20  Sunny

# %%
ddff = group.std()
ddff
# Out:
#         temperature  windspeed
# event
# Cloudy     6.110101   2.516611
# Fog        1.414214   2.121320
# Rain      42.426407   0.707107
# Snow            NaN        NaN
# Sunny     26.495283   6.898067

# %%
group.describe()
# Out:
#        temperature                                                        \
#              count       mean        std   min    25%   50%    75%   max
# event
# Cloudy         3.0  48.666667   6.110101  42.0  46.00  50.0  52.00  54.0
# Fog            2.0  86.000000   1.414214  85.0  85.50  86.0  86.50  87.0
# Rain           2.0  62.000000  42.426407  32.0  47.00  62.0  77.00  92.0
# Snow           1.0  28.000000        NaN  28.0  28.00  28.0  28.00  28.0
# Sunny          4.0  51.000000  26.495283  33.0  35.25  40.5  56.25  90.0
#
#        windspeed
#            count       mean       std   min    25%   50%    75%   max
# event
# Cloudy       3.0  10.333333  2.516611   8.0   9.00  10.0  11.50  13.0
# Fog          2.0  13.500000  2.121320  12.0  12.75  13.5  14.25  15.0
# Rain         2.0   5.500000  0.707107   5.0   5.25   5.5   5.75   6.0
# Snow         1.0  12.000000       NaN  12.0  12.00  12.0  12.00  12.0
# Sunny        4.0   9.750000  6.898067   5.0   6.50   7.0  10.25  20.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("weather_by_cities.csv")
gr = df.groupby("city")
gr.get_group('new york')
gr.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df1 = pd.DataFrame({
    "Name": ["salman khan", "amir khan", "rajkumar rao"],
    "Age": [55, 56, 35],
    'city': ['mumbai', 'delhi', 'kolkata']
})
df1
# Out:
#            Name  Age     city
# 0   salman khan   55   mumbai
# 1     amir khan   56    delhi
# 2  rajkumar rao   35  kolkata

# %%
df2 = pd.DataFrame({
    'Name': ['amir khan', 'rajkumar rao', 'salman khan'],
    "income": [50000, 40000, 70000],
    'movie': ['pk', 'shadi  mai jorur ana', 'bharat']
}, index= [1,2,0])
df2
# Out:
#            Name  income                 movie
# 1     amir khan   50000                    pk
# 2  rajkumar rao   40000  shadi  mai jorur ana
# 0   salman khan   70000                bharat

# %%
df4 = pd.DataFrame({
    "Name": ['shahid kapor', 'ranbir kapor', 'sarman joshi'],
    'Age': [34, 35, 43],
    'city': ['goa', 'pune', 'tamil']
})
df4
# Out:
#            Name  Age   city
# 0  shahid kapor   34    goa
# 1  ranbir kapor   35   pune
# 2  sarman joshi   43  tamil

# %%
df3 = pd.concat([df1, df2['income'], df2['movie']], axis= 0)
df3
# Out:
#                       0         Actor   Age     city
# 1                   NaN   salman khan  55.0   mumbai
# 2                   NaN     amir khan  56.0    delhi
# 3                   NaN  rajkumar rao  35.0  kolkata
# 2                 50000           NaN   NaN      NaN
# 3                 40000           NaN   NaN      NaN
# 1                 70000           NaN   NaN      NaN
# 2                    pk           NaN   NaN      NaN
# 3  shadi  mai jorur ana           NaN   NaN      NaN
# 1                bharat           NaN   NaN      NaN

# %%
df6 = pd.DataFrame({
    'Name' :['karina kapor', 'bidda balan', 'sharda kapor'],
    'Age': [33,44, 32],
    'city': ['bandara', 'hydravad', 'telgue']
})
df6
# Out:
#            Name  Age      city
# 0  karina kapor   33   bandara
# 1   bidda balan   44  hydravad
# 2  sharda kapor   32    telgue

# %%
df5 = pd.concat([df1, df4, df6])
df5
# Out:
#            Name  Age      city
# 0   salman khan   55    mumbai
# 1     amir khan   56     delhi
# 2  rajkumar rao   35   kolkata
# 0  shahid kapor   34       goa
# 1  ranbir kapor   35      pune
# 2  sarman joshi   43     tamil
# 0  karina kapor   33   bandara
# 1   bidda balan   44  hydravad
# 2  sharda kapor   32    telgue

# %%
df = pd.read_csv("HistoricalQuotes.csv", parse_dates= ['Date'])
df.tail()
# Out:
#          Date  Close/Last    Volume      Open      High       Low
# 16 2020-02-26     $292.65  49678430   $286.53   $297.88    $286.5
# 17 2020-02-25     $288.08  57668360   $300.95   $302.53   $286.13
# 18 2020-02-24     $298.18  55548830   $297.26   $304.18   $289.23
# 19 2020-02-21     $313.05  32426420   $318.62   $320.45    $310.5
# 20 2020-02-20      $320.3  25141490   $322.63   $324.65   $318.21

# %%
df.set_index("Date",inplace= True)
df
# Out:
#             Close/Last     Volume       Open      High       Low
# Date
# 2020-03-19     $244.78   67964260   $247.385   $252.84   $242.61
# 2020-03-18     $246.67   75058410    $239.77      $250   $237.12
# 2020-03-17     $252.86   81013970    $247.51   $257.61    $238.4
# 2020-03-16     $242.21   80605870    $241.95   $259.08      $240
# 2020-03-13     $277.97   92683030    $264.89   $279.92   $252.95
# 2020-03-12     $248.23  104618500    $255.94      $270      $248
# 2020-03-11     $275.43   64094970    $277.39   $281.22   $271.86
# 2020-03-10     $285.34   71322520    $277.14   $286.44   $269.37
# 2020-03-09     $266.17   71686210    $263.75   $278.09      $263
# 2020-03-06     $289.03   56544250       $282   $290.82   $281.23
# 2020-03-05     $292.92   46893220    $295.52   $299.55   $291.41
# 2020-03-04     $302.74   54794570    $296.44    $303.4   $293.13
# 2020-03-03     $289.32   79868850    $303.67      $304    $285.8
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2020-03-19', '2020-03-18', '2020-03-17', '2020-03-16',
#                '2020-03-13', '2020-03-12', '2020-03-11', '2020-03-10',
#                '2020-03-09', '2020-03-06', '2020-03-05', '2020-03-04',
#                '2020-03-03', '2020-03-02', '2020-02-28', '2020-02-27',
#                '2020-02-26', '2020-02-25', '2020-02-24', '2020-02-21',
#                '2020-02-20'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
df['2020-02']
# Out:
#             Close/Last     Volume      Open      High       Low
# Date
# 2020-02-28     $273.36  106721200   $257.26   $278.41   $256.37
# 2020-02-27     $273.52   80151380    $281.1      $286   $272.96
# 2020-02-26     $292.65   49678430   $286.53   $297.88    $286.5
# 2020-02-25     $288.08   57668360   $300.95   $302.53   $286.13
# 2020-02-24     $298.18   55548830   $297.26   $304.18   $289.23
# 2020-02-21     $313.05   32426420   $318.62   $320.45    $310.5
# 2020-02-20      $320.3   25141490   $322.63   $324.65   $318.21

# %%
df.columns
# Out:
# Index([' Close/Last', ' Volume', ' Open', ' High', ' Low'], dtype='object')

# %%
df.loc['2020-02': , [' Volume']]
# Out:
#                Volume
# Date
# 2020-02-28  106721200
# 2020-02-27   80151380
# 2020-02-26   49678430
# 2020-02-25   57668360
# 2020-02-24   55548830
# 2020-02-21   32426420
# 2020-02-20   25141490

# %%
df.loc['2020-02': , [' Volume']].plot()

# %%
dt = pd.date_range(start='2020-01-01', end= '2020-01-31', freq= 'B')
dt
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-20', '2020-01-21', '2020-01-22',
#                '2020-01-23', '2020-01-24', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31'],
#               dtype='datetime64[ns]', freq='B')

# %%
df5
# Out:
#            Name  Age      city
# 0   salman khan   55    mumbai
# 1     amir khan   56     delhi
# 2  rajkumar rao   35   kolkata
# 0  shahid kapor   34       goa
# 1  ranbir kapor   35      pune
# 2  sarman joshi   43     tamil
# 0  karina kapor   33   bandara
# 1   bidda balan   44  hydravad
# 2  sharda kapor   32    telgue

# %%
dt = pd.date_range(start= '2020-01-01', periods= 9, freq= "H")
dt
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 01:00:00',
#                '2020-01-01 02:00:00', '2020-01-01 03:00:00',
#                '2020-01-01 04:00:00', '2020-01-01 05:00:00',
#                '2020-01-01 06:00:00', '2020-01-01 07:00:00',
#                '2020-01-01 08:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
df5.set_index(dt, inplace= True)
df5
# Out:
#                     Name  Age      city
# 2020-01-01   salman khan   55    mumbai
# 2020-01-02     amir khan   56     delhi
# 2020-01-03  rajkumar rao   35   kolkata
# 2020-01-06  shahid kapor   34       goa
# 2020-01-07  ranbir kapor   35      pune
# 2020-01-08  sarman joshi   43     tamil
# 2020-01-09  karina kapor   33   bandara
# 2020-01-10   bidda balan   44  hydravad
# 2020-01-13  sharda kapor   32    telgue
