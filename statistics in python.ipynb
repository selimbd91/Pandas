# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
lst1 = [10, 15, 20, 23, 12]
names = ['bangla', 'english', 'math', 'physics', 'python']
plt.pie(lst1, labels = names, explode= [0.1, 0, 0.3, 0, 0], shadow= True, autopct= '%1.1f%%')
plt.show()
