# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('ted.csv')
df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
df.shape
# Out:
# (2550, 17)

# %%
df.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views'],
#       dtype='object')

# %%
df.dtypes
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# dtype: object

# %%
df.isna().sum()
# Out:
# comments              0
# description           0
# duration              0
# event                 0
# film_date             0
# languages             0
# main_speaker          0
# name                  0
# num_speaker           0
# published_date        0
# ratings               0
# related_talks         0
# speaker_occupation    6
# tags                  0
# title                 0
# url                   0
# views                 0
# dtype: int64

# %%
df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
df1= df.sort_values(by= 'comments')
df1.tail()
# Out:
#       comments                                        description  duration  \
# 1787      2673  Our consciousness is a fundamental aspect of o...      1117
# 201       2877  Jill Bolte Taylor got a research opportunity f...      1099
# 644       3356  Questions of good and evil, right and wrong ar...      1386
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 96        6404  Richard Dawkins urges all atheists to openly s...      1750
#
#         event   film_date  languages       main_speaker  \
# 1787  TED2014  1395100800         33     David Chalmers
# 201   TED2008  1204070400         49  Jill Bolte Taylor
# 644   TED2010  1265846400         39         Sam Harris
# 0     TED2006  1140825600         60       Ken Robinson
# 96    TED2002  1012608000         42    Richard Dawkins
#
#                                                    name  num_speaker  \
# 1787  David Chalmers: How do you explain consciousness?            1
# ...

# %%
d = []

for idx, val in enumerate(df.speaker_occupation):
    if isinstance(val, float) and val != val:
        d.append(idx)

# %%
ddff = df.loc[d,:]
ddff
# Out:
#       comments                                        description  duration  \
# 1113       145  After a crisis, how can we tell if water is sa...       217
# 1192       122  The Pirate Party fights for transparency, anon...      1097
# 1220       257  As you surf the Web, information is being coll...       399
# 1656       140  In this lovely talk, TED Fellow Ryan Holladay ...       389
# 1911        48  What do you do with an outdated encyclopedia i...       366
# 1949        70  Photographer Boniface Mwangi wanted to protest...       440
#
#                       event   film_date  languages     main_speaker  \
# 1113         TEDGlobal 2011  1310601600         38    Sonaar Luthra
# 1192           TEDxObserver  1331424000         10   Rick Falkvinge
# 1220                TED2012  1330473600         32      Gary Kovacs
# 1656  TED@BCG San Francisco  1383091200         33    Ryan Holladay
# 1911          TEDYouth 2014  1415059200         34    Brian Dettmer
# ...

# %%
df['comments_per_view'] = df['comments'] / df['views']
df.sort_values(by= 'comments_per_view').tail()
# Out:
#      comments                                        description  duration  \
# 954      2492  Janet Echelman found her true voice as an arti...       566
# 694      1502  Filmmaker Sharmeen Obaid-Chinoy takes on a ter...       489
# 96       6404  Richard Dawkins urges all atheists to openly s...      1750
# 803       834  David Bismark demos a new system for voting th...       422
# 744       649  Hours before New York lawmakers rejected a key...       453
#
#                      event   film_date  languages           main_speaker  \
# 954                TED2011  1299110400         35         Janet Echelman
# 694                TED2010  1265760000         32  Sharmeen Obaid-Chinoy
# 96                 TED2002  1012608000         42        Richard Dawkins
# 803         TEDGlobal 2010  1279065600         36          David Bismark
# 744  New York State Senate  1259712000          0        Diane J. Savino
#
#                                                   name  num_speaker  \
# ...

# %%
df['views per comment'] = df['views'] / df['comments']
df.sort_values(by= 'views per comment', inplace= True)

# %%
df
# Out:
#       comments                                        description  duration  \
# 744        649  Hours before New York lawmakers rejected a key...       453
# 803        834  David Bismark demos a new system for voting th...       422
# 96        6404  Richard Dawkins urges all atheists to openly s...      1750
# 694       1502  Filmmaker Sharmeen Obaid-Chinoy takes on a ter...       489
# 954       2492  Janet Echelman found her true voice as an arti...       566
# ...        ...                                                ...       ...
# 2494         7  Jimmy Lin is developing technologies to catch ...       730
# 2528         3  Digital archaeologist Chance Coughenour is usi...       717
# 2542         3  In the century-old statues that occupy Cape To...       795
# 2501         3  Meet Françoise Mouly, The New Yorker's art dir...       509
# 2534         2  What the astronauts felt when they saw Earth f...       725
#
# ...

# %%
df.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views', 'comments_per_view', 'views per comment'],
#       dtype='object')

# %%
df.index
# Out:
# Int64Index([ 744,  803,   96,  694,  954,  840,  876, 1787,  661,  561,
#             ...
#             2273, 2392, 2407, 2114, 2313, 2494, 2528, 2542, 2501, 2534],
#            dtype='int64', length=2550)

# %%
df.shape
# Out:
# (2550, 19)

# %%
df.columns
# Out:
# Index(['index', 'comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views', 'comments_per_view', 'views per comment'],
#       dtype='object')

# %%
df.reset_index(drop= True,inplace=True)

# %%
df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
# ...

# %%
df['event']
# Out:
# 0            TED2006
# 1            TED2006
# 2            TED2006
# 3            TED2006
# 4            TED2006
#             ...
# 2545         TED2017
# 2546         TED2017
# 2547         TED2017
# 2548    TEDxMileHigh
# 2549         TED2017
# Name: event, Length: 2550, dtype: object

# %%
len(df['event'].unique())
# Out:
# 355

# %%
ddf = df['event']

# %%
ddff = ddf.replace('[A-Za-z]', '',regex= True)
ddff
# Out:
# 0       2006
# 1       2006
# 2       2006
# 3       2006
# 4       2006
#         ...
# 2545    2017
# 2546    2017
# 2547    2017
# 2548
# 2549    2017
# Name: event, Length: 2550, dtype: object

# %%
type(ddff)
# Out:
# pandas.core.series.Series

# %%
ddff.dtypes
# Out:
# dtype('O')

# %%
ddff[306]
# Out:
# '  '

# %%
ddx = pd.to_numeric(ddff, errors= 'coerce')

# %%
ddx.shape
# Out:
# (2550,)

# %%
ddx[ddx > 1950].shape
# Out:
# (1813,)

# %%
ddx[ddx > 2000].plot(kind= 'hist', bins= 20)

# %%
len(ddx.unique())
# Out:
# 23

# %%
df.sample(10)
# Out:
#       comments                                        description  duration  \
# 2447       115  How can humans be so compassionate and altruis...       951
# 2384        93  Something is very wrong with the news industry...       517
# 2453       259  Why are we so deadlocked on climate, and what ...       787
# 1712        42  Do you have a TED Talk inside, just bursting t...       277
# 643         73  Where does creative inspiration spring from? A...      1274
# 27          95  "Freakonomics" author Steven Levitt presents n...      1275
# 2310        49  Americanization and globalization have basical...       937
# 274         90  All humans share some common bits of DNA, pass...      1253
# 121        145  Jonathan Harris wants to make sense of the emo...      1030
# 1176       241  Comic author Rob Reid unveils Copyright Math (...       311
#
#                  event   film_date  languages     main_speaker  \
# 2447           TED2017  1492992000         20  Robert Sapolsky
# ...

# %%
df.head(5)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
df.shape
# Out:
# (2550, 17)

# %%
df['my date'] = ddx

# %%
df.shape
# Out:
# (2550, 18)

# %%
df[['event', 'my date']]
# Out:
#              event  my date
# 0          TED2006   2006.0
# 1          TED2006   2006.0
# 2          TED2006   2006.0
# 3          TED2006   2006.0
# 4          TED2006   2006.0
# ...            ...      ...
# 2545       TED2017   2017.0
# 2546       TED2017   2017.0
# 2547       TED2017   2017.0
# 2548  TEDxMileHigh      NaN
# 2549       TED2017   2017.0
#
# [2550 rows x 2 columns]

# %%
df['school date time'] = pd.to_datetime(df['film_date'], unit= 's')

# %%
df[['event', 'my date', 'film_date', 'school date time']].sample(10)
# Out:
#                      event  my date   film_date school date time
# 29                 TED2004   2004.0  1075680000       2004-02-02
# 1313              TEDxMaui      NaN  1327190400       2012-01-22
# 137                TED2007   2007.0  1173398400       2007-03-09
# 1432      TEDxThessaloniki      NaN  1336780800       2012-05-12
# 2494               TED2017   2017.0  1492992000       2017-04-24
# 1760               TED2014   2014.0  1395100800       2014-03-18
# 846   TEDSalon London 2010   2010.0  1289433600       2010-11-11
# 2358               TED@IBM      NaN  1479168000       2016-11-15
# 475                TED2009   2009.0  1233878400       2009-02-06
# 763                TEDxYYC      NaN  1267142400       2010-02-26

# %%
ddx.isna().sum()
# Out:
# 723

# %%
mama = df['school date time'].dt.year.value_counts()

# %%
type(mama)
# Out:
# pandas.core.series.Series

# %%
mama.head()
# Out:
# 2013    270
# 2011    270
# 2010    267
# 2012    267
# 2016    246
# Name: school date time, dtype: int64

# %%
kk= mama.sort_index()
kk.plot()

# %%
kk
# Out:
# 1972      1
# 1983      1
# 1984      1
# 1990      1
# 1991      1
# 1994      1
# 1998      6
# 2001      5
# 2002     27
# 2003     33
# 2004     33
# 2005     66
# 2006     50
# 2007    114
# 2008     84
# 2009    232
# 2010    267
# 2011    270
# 2012    267
# 2013    270
# 2014    237
# 2015    239
# 2016    246
# 2017     98
# Name: school date time, dtype: int64
