# %%
import matplotlib.pyplot as plt
import numpy as np
#%matplotlib inline

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes([0, 0, 1, 1])
#ax1.plot(x, x**2)
ax2 = fig1.add_axes([1.2, 0, 0.5, 0.5])
ax2.set_title("hello brother")
# Out:
# Text(0.5, 1.0, 'hello brother')

# %%
x = np.linspace(-100, 100, 100)
y = np.random.randint(4, 23, 100)

fig, ax = plt.subplots()
#display(fig)
#display(type(fig))
#type(fig)

# %%
figg, axx = plt.subplots(1, 3)

#ak = figg.add_axes([0.1, 0.2, 0.5, 0.5])
aa = [x, x**2, x**3] 
ayy = ["x", "x^2", "x^3"]

for i, j in enumerate(axx):
    axx[i].plot(x,aa[i])
    axx[i].set_title(ayy[i])
figg.tight_layout()

# %%
fig, ax = plt.subplots()
ax.bar([1,2, 3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-4915d4c8cc60> in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.bar([1,2, 3])
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
ff, xx = plt.subplots(1,2)
#xx[1,0].plot(x, x**2, "r")
for ax in xx:
    ax.plot(x, x**2)

# %%
arr = np.array([2, 3, 4, 5])
for index, val in enumerate(arr):
    print(f"{index} ---> {val}")
# Out:
# 0 ---> 2
# 1 ---> 3
# 2 ---> 4
# 3 ---> 5

# %%
fig, ax = plt.subplots(figsize= (8, 6))

# %%
fig, ax = plt.subplots(figsize= (4, 3))
ax.plot(x,x**2, color= "r", label= "x^2")
ax.plot(x, x**3, color= "g", label= "x^3")
ax.legend()
ax.set_ylim([0, 5000])
# Out:
# (0, 5000)

# %%
help(plt.bar)
# Out:
# Help on function bar in module matplotlib.pyplot:
#
# bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)
#     Make a bar plot.
#
#     The bars are positioned at *x* with the given *align*\ment. Their
#     dimensions are given by *width* and *height*. The vertical baseline
#     is *bottom* (default 0).
#
#     Each of *x*, *height*, *width*, and *bottom* may either be a scalar
#     applying to all bars, or it may be a sequence of length N providing a
#     separate value for each bar.
#
#     Parameters
#     ----------
#     x : sequence of scalars
#         The x coordinates of the bars. See also *align* for the
#         alignment of the bars to the coordinates.
#
#     height : scalar or sequence of scalars
#         The height(s) of the bars.
#
#     width : scalar or array-like, optional
#         The width(s) of the bars (default: 0.8).
#
#     bottom : scalar or array-like, optional
#         The y coordinate(s) of the bars bases (default: 0).
# ...

# %%
fig, ax = plt.subplots()
ax.bar([1, 2, 3, 4, 5, 6, 7,8 ,9], height=np.arange(1, 10), width= 0.2)
# Out:
# <BarContainer object of 9 artists>

# %%
# !pip install plotly
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-cp37-none-any.whl size=11435 sha256=efe5cb5a868c38143d4308f1f1bb8e9aad791cdbdfb212fc784a7d4bb02b9a37
#   Stored in directory: C:\Users\LENOVO\AppData\Local\pip\Cache\wheels\d7\a9\33\acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
# Successfully built retrying
# ...

# %%
# !pip install cufflinks
# Out:
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.0-cp37-none-any.whl size=68551 sha256=7bb35e5be857d838b85dce66fce8ae796a3d40138996f039a85efb5bb2d1da84
#   Stored in directory: C:\Users\LENOVO\AppData\Local\pip\Cache\wheels\44\d7\dc\e830ab00bc2dd3b2731295103baa070f8cbdda8891f71a7a8d
# Successfully built cufflinks
# ...
