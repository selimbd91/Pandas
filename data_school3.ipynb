# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ufo_df = pd.read_csv('http://bit.ly/uforeports', nrows= 3)
ufo_df
# Out:
#           City  Colors Reported Shape Reported State             Time
# 0       Ithaca              NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro              NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke              NaN           OVAL    CO  2/15/1931 14:00

# %%
for idx, row_df in ufo_df.iterrows():
    print(row_df.City)
# Out:
# Ithaca
# Willingboro
# Holyoke

# %%
drink_df = pd.read_csv('http://bit.ly/drinksbycountry')
drink_df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
xx = drink_df.select_dtypes(include= np.object)
xx
# Out:
#          country      continent
# 0    Afghanistan           Asia
# 1        Albania         Europe
# 2        Algeria         Africa
# 3        Andorra         Europe
# 4         Angola         Africa
# ..           ...            ...
# 188    Venezuela  South America
# 189      Vietnam           Asia
# 190        Yemen           Asia
# 191       Zambia         Africa
# 192     Zimbabwe         Africa
#
# [193 rows x 2 columns]

# %%
xx
# Out:
#          country      continent
# 0    Afghanistan           Asia
# 1        Albania         Europe
# 2        Algeria         Africa
# 3        Andorra         Europe
# 4         Angola         Africa
# ..           ...            ...
# 188    Venezuela  South America
# 189      Vietnam           Asia
# 190        Yemen           Asia
# 191       Zambia         Africa
# 192     Zimbabwe         Africa
#
# [193 rows x 2 columns]

# %%
drink_df.describe(include='float64')
# Out:
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drink_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
ss = drink_df.drop(labels= 0, axis= 0)
ss
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 1              Albania             89              132             54
# 2              Algeria             25                0             14
# 3              Andorra            245              138            312
# 4               Angola            217               57             45
# 5    Antigua & Barbuda            102              128             45
# ..                 ...            ...              ...            ...
# 188          Venezuela            333              100              3
# 189            Vietnam            111                2              1
# 190              Yemen              6                0              0
# 191             Zambia             32               19              4
# 192           Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 1                             4.9         Europe
# ...

# %%
drink_df.mean(axis= 0)
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
chip_df = pd.read_csv('http://bit.ly/chiporders', sep='\t')
chip_df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chip_df.item_name = chip_df.item_name.str.upper()

# %%
chip_df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           CHIPS AND FRESH TOMATO SALSA
# 1         1         1                                   IZZE
# 2         1         1                       NANTUCKET NECTAR
# 3         1         1  CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4         2         2                           CHICKEN BOWL
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chip_df.item_name.str.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-68ca56c68c55> in <module>
# ----> 1 chip_df.item_name.str.sort()
#
# AttributeError: 'StringMethods' object has no attribute 'sort'

# %%
chip_df.loc[chip_df.item_name.str.contains('CHICKEN'),['item_name', 'item_price']]
# Out:
#                  item_name item_price
# 4             CHICKEN BOWL    $16.98
# 5             CHICKEN BOWL    $10.98
# 11    CHICKEN CRISPY TACOS     $8.75
# 12      CHICKEN SOFT TACOS     $8.75
# 13            CHICKEN BOWL    $11.25
# ...                    ...        ...
# 4604          CHICKEN BOWL     $8.75
# 4615    CHICKEN SOFT TACOS     $8.75
# 4619    CHICKEN SALAD BOWL    $11.25
# 4620    CHICKEN SALAD BOWL     $8.75
# 4621    CHICKEN SALAD BOWL     $8.75
#
# [1560 rows x 2 columns]

# %%
chip_df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           CHIPS AND FRESH TOMATO SALSA
# 1            1         1                                   IZZE
# 2            1         1                       NANTUCKET NECTAR
# 3            1         1  CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4            2         2                           CHICKEN BOWL
# ...        ...       ...                                    ...
# 4617      1833         1                          STEAK BURRITO
# 4618      1833         1                          STEAK BURRITO
# 4619      1834         1                     CHICKEN SALAD BOWL
# 4620      1834         1                     CHICKEN SALAD BOWL
# 4621      1834         1                     CHICKEN SALAD BOWL
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
chip_df.choice_description.str.replace('[\[\]]', '', regex=True)
# Out:
# 0                                                     NaN
# 1                                              Clementine
# 2                                                   Apple
# 3                                                     NaN
# 4       Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
#                               ...
# 4617    Fresh Tomato Salsa, Rice, Black Beans, Sour Cr...
# 4618    Fresh Tomato Salsa, Rice, Sour Cream, Cheese, ...
# 4619    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# 4620       Fresh Tomato Salsa, Fajita Vegetables, Lettuce
# 4621    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# Name: choice_description, Length: 4622, dtype: object

# %%
chip_df.replace({'choice_description':'[\[\]]'}, '', regex=True)
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           CHIPS AND FRESH TOMATO SALSA
# 1            1         1                                   IZZE
# 2            1         1                       NANTUCKET NECTAR
# 3            1         1  CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4            2         2                           CHICKEN BOWL
# ...        ...       ...                                    ...
# 4617      1833         1                          STEAK BURRITO
# 4618      1833         1                          STEAK BURRITO
# 4619      1834         1                     CHICKEN SALAD BOWL
# 4620      1834         1                     CHICKEN SALAD BOWL
# 4621      1834         1                     CHICKEN SALAD BOWL
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
chip_df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
chip_df.item_price.str.replace('$','').astype(np.float64)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
chip_df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
chip_df['item_price'] = chip_df.item_price.astype(np.float64)

# %%
chip_df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           CHIPS AND FRESH TOMATO SALSA
# 1            1         1                                   IZZE
# 2            1         1                       NANTUCKET NECTAR
# 3            1         1  CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4            2         2                           CHICKEN BOWL
# ...        ...       ...                                    ...
# 4617      1833         1                          STEAK BURRITO
# 4618      1833         1                          STEAK BURRITO
# 4619      1834         1                     CHICKEN SALAD BOWL
# 4620      1834         1                     CHICKEN SALAD BOWL
# 4621      1834         1                     CHICKEN SALAD BOWL
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
chip_df.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
drink_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
grp = drink_df.groupby(by= 'continent')

# %%
grp.get_group('Asia')
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 19                 Bhutan             23                0              0
# 24                 Brunei             31                2              1
# 30               Cambodia             57               65              1
# 36                  China             79              192              8
# 46            North Korea              0                0              0
# 77                  India              9              114              0
# 78              Indonesia              5                1              0
# 79                   Iran              0                0              0
# 80                   Iraq              9                3              0
# ...

# %%
xx = []
for idx, val in drink_df.iterrows():
    if val.continent == 'Asia':
        xx.append(idx)

drink_df.loc[xx]
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 19                 Bhutan             23                0              0
# 24                 Brunei             31                2              1
# 30               Cambodia             57               65              1
# 36                  China             79              192              8
# 46            North Korea              0                0              0
# 77                  India              9              114              0
# 78              Indonesia              5                1              0
# 79                   Iran              0                0              0
# 80                   Iraq              9                3              0
# ...

# %%
xx = drink_df.groupby(by='continent').beer_servings.agg(['mean', 'count', 'max'])
xx.plot(kind= 'bar')

# %%
type(xx)
# Out:
# pandas.core.series.Series

# %%
xx.index
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol'],
#       dtype='object')

# %%
xx[['beer_servings','spirit_servings']]
# Out:
# beer_servings      37.045455
# spirit_servings    60.840909
# dtype: float64

# %%
movie_df = pd.read_csv('http://bit.ly/imdbratings')
movie_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movie_df.genre.head()
# Out:
# 0     Crime
# 1     Crime
# 2     Crime
# 3    Action
# 4     Crime
# Name: genre, dtype: object

# %%
movie_df.genre.value_counts(ascending=True)
# Out:
# History        1
# Fantasy        1
# Family         2
# Film-Noir      3
# Sci-Fi         5
# Thriller       5
# Western        9
# Mystery       16
# Horror        29
# Animation     62
# Adventure     75
# Biography     77
# Crime        124
# Action       136
# Comedy       156
# Drama        278
# Name: genre, dtype: int64

# %%
import time

# %%
localtime = time.asctime(time.localtime(time.time()))
localtime
# Out:
# 'Fri Mar 27 19:32:51 2020'

# %%
type(localtime)
# Out:
# str

# %%
time.localtime(time.time())
# Out:
# time.struct_time(tm_year=2020, tm_mon=3, tm_mday=27, tm_hour=19, tm_min=34, tm_sec=15, tm_wday=4, tm_yday=87, tm_isdst=0)

# %%
time.asctime()
# Out:
# 'Fri Mar 27 19:54:10 2020'

# %%
time.ctime()
# Out:
# 'Fri Mar 27 19:54:38 2020'

# %%
time.time()
# Out:
# 1585335295.877198

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2020, tm_mon=3, tm_mday=27, tm_hour=19, tm_min=55, tm_sec=7, tm_wday=4, tm_yday=87, tm_isdst=0)

# %%
time.gmtime()
# Out:
# time.struct_time(tm_year=2020, tm_mon=3, tm_mday=27, tm_hour=18, tm_min=55, tm_sec=24, tm_wday=4, tm_yday=87, tm_isdst=0)

# %%
time.ctime(1585335295.877198)
# Out:
# 'Fri Mar 27 19:54:55 2020'

# %%
time.asctime(time.localtime())
# Out:
# 'Fri Mar 27 19:59:44 2020'

# %%
x = time.localtime()
type(x)
# Out:
# time.struct_time

# %%
time.asctime(x)
# Out:
# 'Fri Mar 27 20:00:10 2020'

# %%
time.mktime(time.localtime())
# Out:
# 1585337610.0

# %%
j = time.localtime()
j
# Out:
# time.struct_time(tm_year=2020, tm_mon=3, tm_mday=27, tm_hour=20, tm_min=13, tm_sec=58, tm_wday=4, tm_yday=87, tm_isdst=0)

# %%
x = time.strftime('%d-%m-%Y %H:%M:%S %p')
x
# Out:
# '27-03-2020 20:20:45 PM'

# %%
y = '08 Dec 2018'
r = time.strptime(y, '%d %b %Y')
r
# Out:
# time.struct_time(tm_year=2018, tm_mon=12, tm_mday=8, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=5, tm_yday=342, tm_isdst=-1)

# %%
import datetime

# %%
print(datetime.datetime(year= 1991, month= 2, day= 10, hour= 2, minute= 23, second= 43, microsecond= 45))
# Out:
# 1991-02-10 02:23:43.000045

# %%
x = datetime.datetime.today()
x
# Out:
# datetime.datetime(2020, 3, 27, 20, 37, 30, 87918)

# %%
x.year
# Out:
# 2020

# %%
x.hour
# Out:
# 20

# %%
x.minute
# Out:
# 37

# %%
xx = datetime.date(1991, 2,10)

# %%
xx.day
# Out:
# 10

# %%
yy = datetime.time(20, 40, 30)

# %%
yy
# Out:
# datetime.time(20, 40, 30)

# %%
yy.hour
# Out:
# 20

# %%
yy.minute
# Out:
# 40

# %%
y = 8
if y>= 5:
    print('equal 5')
elif y>5:
    print('greaterh than 5')
else:
    print('less than 5')
# Out:
# equal 5

# %%
x = datetime.timedelta(days= 20)
y = datetime.timedelta(days = 2)

x-y
# Out:
# datetime.timedelta(days=18)

# %%
movie_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movie_df.genre.value_counts(normalize= True)
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Thriller     0.005107
# Sci-Fi       0.005107
# Film-Noir    0.003064
# Family       0.002043
# Fantasy      0.001021
# History      0.001021
# Name: genre, dtype: float64

# %%
movie_df.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movie_df.genre.nunique()
# Out:
# 16

# %%
movie_df.duration.isnull().sum()
# Out:
# 0

# %%
movie_df.sort_values(by= ['duration'], axis= 0)
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %%
pd.crosstab(movie_df.title, movie_df.genre)
# Out:
# genre                  Action  Adventure  Animation  Biography  Comedy  Crime  \
# title
# (500) Days of Summer        0          0          0          0       1      0
# 12 Angry Men                0          0          0          0       0      0
# 12 Years a Slave            0          0          0          1       0      0
# 127 Hours                   0          1          0          0       0      0
# 2001: A Space Odyssey       0          0          0          0       0      0
# ...                       ...        ...        ...        ...     ...    ...
# Zero Dark Thirty            0          0          0          0       0      0
# Zodiac                      0          0          0          0       0      1
# Zombieland                  0          0          0          0       1      0
# Zulu                        0          0          0          0       0      0
# [Rec]                       0          0          0          0       0      0
#
# ...

# %%
movie_df.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movie_df.duration.agg(['count', 'mean', 'std', 'min', 'median', 'max'])
# Out:
# count     979.000000
# mean      120.979571
# std        26.218010
# min        64.000000
# median    117.000000
# max       242.000000
# Name: duration, dtype: float64

# %%
movie_df.duration.describe(include= np.number)
# Out:
# count    979.000000
# mean     120.979571
# std       26.218010
# min       64.000000
# 25%      102.000000
# 50%      117.000000
# 75%      134.000000
# max      242.000000
# Name: duration, dtype: float64

# %%
movie_df.duration.value_counts()
# Out:
# 112    23
# 113    22
# 102    20
# 101    20
# 129    19
#        ..
# 180     1
# 177     1
# 168     1
# 166     1
# 64      1
# Name: duration, Length: 133, dtype: int64

# %%
movie_df.genre.value_counts().index
# Out:
# Index(['Drama', 'Comedy', 'Action', 'Crime', 'Biography', 'Adventure',
#        'Animation', 'Horror', 'Mystery', 'Western', 'Thriller', 'Sci-Fi',
#        'Film-Noir', 'Family', 'Fantasy', 'History'],
#       dtype='object')

# %%
ax = sns.barplot(x= movie_df.genre.value_counts().index, y= movie_df.genre.value_counts())

# %%
ufo_df
# Out:
#           City  Colors Reported Shape Reported State             Time
# 0       Ithaca              NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro              NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke              NaN           OVAL    CO  2/15/1931 14:00

# %%
xx = ufo_df.fillna({
    'Colors Reported': 12,
    'State': 13
})
xx
# Out:
#           City  Colors Reported Shape Reported State             Time
# 0       Ithaca             12.0       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             12.0          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             12.0           OVAL    CO  2/15/1931 14:00

# %%
movie_df = pd.read_csv('http://bit.ly/uforeports')
movie_df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
movie_df.shape
# Out:
# (18241, 5)

# %%
movie_df.dropna(how='all').shape
# Out:
# (18241, 5)

# %%
movie_df.dropna(subset= ['City', 'Shape Reported'], how= 'all').shape
# Out:
# (18237, 5)

# %%
movie_df['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
movie_df.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
movie_df.fillna(value= 'color')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca           color       TRIANGLE    NY
# 1               Willingboro           color          OTHER    NJ
# 2                   Holyoke           color           OVAL    CO
# 3                   Abilene           color           DISK    KS
# 4      New York Worlds Fair           color          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park           color       TRIANGLE    IL
# 18237           Spirit Lake           color           DISK    IA
# 18238           Eagle River           color          color    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor           color           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
movie_df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
movie_df.shape
# Out:
# (18241, 5)

# %%
movie_df.set_index('City', inplace= True)

# %%
movie_df.head()
# Out:
#                      Colors Reported Shape Reported State             Time
# City
# Ithaca                           NaN       TRIANGLE    NY   6/1/1930 22:00
# Willingboro                      NaN          OTHER    NJ  6/30/1930 20:00
# Holyoke                          NaN           OVAL    CO  2/15/1931 14:00
# Abilene                          NaN           DISK    KS   6/1/1931 13:00
# New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
movie_df.shape
# Out:
# (18241, 4)

# %%
movie_df.reset_index(inplace= True)

# %%
movie_df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
movie_df.set_index('City', inplace= True)

# %%
movie_df.head()
# Out:
#                      Colors Reported Shape Reported State             Time
# City
# Ithaca                           NaN       TRIANGLE    NY   6/1/1930 22:00
# Willingboro                      NaN          OTHER    NJ  6/30/1930 20:00
# Holyoke                          NaN           OVAL    CO  2/15/1931 14:00
# Abilene                          NaN           DISK    KS   6/1/1931 13:00
# New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
movie_df.index
# Out:
# Index([              'Ithaca',          'Willingboro',              'Holyoke',
#                     'Abilene', 'New York Worlds Fair',          'Valley City',
#                 'Crater Lake',                 'Alma',              'Eklutna',
#                     'Hubbard',
#        ...
#                 'Pismo Beach',                 'Lodi',            'Anchorage',
#                    'Capitola',       'Fountain Hills',           'Grant Park',
#                 'Spirit Lake',          'Eagle River',          'Eagle River',
#                        'Ybor'],
#       dtype='object', name='City', length=18241)

# %%
movie_df.index.name= None

# %%
movie_df.head()
# Out:
#                      Colors Reported Shape Reported State             Time
# Ithaca                           NaN       TRIANGLE    NY   6/1/1930 22:00
# Willingboro                      NaN          OTHER    NJ  6/30/1930 20:00
# Holyoke                          NaN           OVAL    CO  2/15/1931 14:00
# Abilene                          NaN           DISK    KS   6/1/1931 13:00
# New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
movie_df.reset_index(inplace=True)

# %%
movie_df.head()
# Out:
#                   index Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
movie_df.rename(columns= {'index': 'country'}, inplace= True)
movie_df.head()
# Out:
#                 country Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
drink_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drink_df.set_index('country', inplace= True)
drink_df.continent
# Out:
# country
# Afghanistan             Asia
# Albania               Europe
# Algeria               Africa
# Andorra               Europe
# Angola                Africa
#                    ...
# Venezuela      South America
# Vietnam                 Asia
# Yemen                   Asia
# Zambia                Africa
# Zimbabwe              Africa
# Name: continent, Length: 193, dtype: object

# %%
drink_df.continent.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Tanzania', 'USA', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=193)

# %%
drink_df.continent.value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
drink_df.continent.value_counts().index
# Out:
# Index(['Africa', 'Europe', 'Asia', 'North America', 'Oceania',
#        'South America'],
#       dtype='object')

# %%
drink_df.continent.value_counts().values
# Out:
# array([53, 45, 44, 23, 16, 12], dtype=int64)

# %%
drink_df
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol      continent
# country
# Afghanistan                           0.0           Asia
# Albania                               4.9         Europe
# Algeria                               0.7         Africa
# ...

# %%
drink_df.head(3).drop('continent', axis= 1)
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
#
#              total_litres_of_pure_alcohol
# country
# Afghanistan                           0.0
# Albania                               4.9
# Algeria                               0.7

# %%
drink_df.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Tanzania', 'USA', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=193)

# %%
drink_df.reset_index(inplace= True)

# %%
drink_df.iloc[0:2,0:3]
# Out:
#        country  beer_servings  spirit_servings
# 0  Afghanistan              0                0
# 1      Albania             89              132
