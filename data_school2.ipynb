# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
movie_df = pd.read_csv('http://bit.ly/imdbratings')
movie_df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movie_df.shape
# Out:
# (979, 6)

# %%
movie_df.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
movie_df.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
ar = []

for i, j in enumerate(movie_df['content_rating']):
    if isinstance(j, float) and j != j:
        ar.append(i)

# %%
movie_df.loc[ar]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
movie_df.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
sns.distplot(movie_df.star_rating, hist= False)

# %%
movie_df.star_rating.mean()
# Out:
# 7.8897854954034985

# %%
sns.lineplot(y= movie_df.star_rating, x= movie_df.star_rating.mean(), data= movie_df, color= 'red')

# %%
movie_df.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movie_df.describe(include= 'all')
# Out:
#         star_rating                            title content_rating  genre  \
# count    979.000000                              979            976    979
# unique          NaN                              975             12     16
# top             NaN  The Girl with the Dragon Tattoo              R  Drama
# freq            NaN                                2            460    278
# mean       7.889785                              NaN            NaN    NaN
# std        0.336069                              NaN            NaN    NaN
# min        7.400000                              NaN            NaN    NaN
# 25%        7.600000                              NaN            NaN    NaN
# 50%        7.800000                              NaN            NaN    NaN
# 75%        8.100000                              NaN            NaN    NaN
# max        9.300000                              NaN            NaN    NaN
#
# ...

# %%
ufo_df = pd.read_csv('http://bit.ly/uforeports')
ufo_df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo_df.size
# Out:
# 91205

# %%
ufo_df.memory_usage
# Out:
# <bound method DataFrame.memory_usage of                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# ...

# %%
ufo_df.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo_df.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
ufo_df['location'] = ufo_df.City + ',' + ufo_df.State
ufo_df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time                 location
# 0        6/1/1930 22:00                Ithaca,NY
# 1       6/30/1930 20:00           Willingboro,NJ
# ...

# %%
ufo_df['Colors_Reported'] = ufo_df['Colors Reported']
ufo_df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time                 location Colors_Reported
# 0        6/1/1930 22:00                Ithaca,NY             NaN
# ...

# %%
ufo_df.rename(columns= {
    'Colors Reported': 'Colors_Reported',
    'Shape Reported': 'Shape_Reported'
}, inplace= True)
ufo_df
# Out:
#                        City Colors_Reported Shape_Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo_df.columns = ['city', 'a', 'b', 'c', 'd']
ufo_df
# Out:
#                        city    a         b   c                 d
# 0                    Ithaca  NaN  TRIANGLE  NY    6/1/1930 22:00
# 1               Willingboro  NaN     OTHER  NJ   6/30/1930 20:00
# 2                   Holyoke  NaN      OVAL  CO   2/15/1931 14:00
# 3                   Abilene  NaN      DISK  KS    6/1/1931 13:00
# 4      New York Worlds Fair  NaN     LIGHT  NY   4/18/1933 19:00
# ...                     ...  ...       ...  ..               ...
# 18236            Grant Park  NaN  TRIANGLE  IL  12/31/2000 23:00
# 18237           Spirit Lake  NaN      DISK  IA  12/31/2000 23:00
# 18238           Eagle River  NaN       NaN  WI  12/31/2000 23:45
# 18239           Eagle River  RED     LIGHT  WI  12/31/2000 23:45
# 18240                  Ybor  NaN      OVAL  FL  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %%
ufo_df.columns = ufo_df.columns.str.replace(' ', '_')
ufo_df
# Out:
#                        City Colors_Reported Shape_Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo_df
# Out:
#                        City Colors_Reported Shape_Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo_df.drop('Colors_Reported', axis= 1, inplace = True)

# %%
ufo_df
# Out:
#                        City Shape_Reported State              Time
# 0                    Ithaca       TRIANGLE    NY    6/1/1930 22:00
# 1               Willingboro          OTHER    NJ   6/30/1930 20:00
# 2                   Holyoke           OVAL    CO   2/15/1931 14:00
# 3                   Abilene           DISK    KS    6/1/1931 13:00
# 4      New York Worlds Fair          LIGHT    NY   4/18/1933 19:00
# ...                     ...            ...   ...               ...
# 18236            Grant Park       TRIANGLE    IL  12/31/2000 23:00
# 18237           Spirit Lake           DISK    IA  12/31/2000 23:00
# 18238           Eagle River            NaN    WI  12/31/2000 23:45
# 18239           Eagle River          LIGHT    WI  12/31/2000 23:45
# 18240                  Ybor           OVAL    FL  12/31/2000 23:59
#
# [18241 rows x 4 columns]

# %%
ufo_df.drop([0, 1], axis= 0, inplace= True)

# %%
ufo_df
# Out:
#                        City Shape_Reported State              Time
# 2                   Holyoke           OVAL    CO   2/15/1931 14:00
# 3                   Abilene           DISK    KS    6/1/1931 13:00
# 4      New York Worlds Fair          LIGHT    NY   4/18/1933 19:00
# 5               Valley City           DISK    ND   9/15/1934 15:30
# 6               Crater Lake         CIRCLE    CA    6/15/1935 0:00
# ...                     ...            ...   ...               ...
# 18236            Grant Park       TRIANGLE    IL  12/31/2000 23:00
# 18237           Spirit Lake           DISK    IA  12/31/2000 23:00
# 18238           Eagle River            NaN    WI  12/31/2000 23:45
# 18239           Eagle River          LIGHT    WI  12/31/2000 23:45
# 18240                  Ybor           OVAL    FL  12/31/2000 23:59
#
# [18239 rows x 4 columns]

# %%
movie_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
xxx = movie_df['duration'].sort_values()
print(xxx.index)
xx = movie_df.loc[xxx.index]
xx
# Out:
# Int64Index([389, 338, 258, 293,  88, 742, 351, 938, 405, 303,
#             ...
#             630, 767,  17, 204,  85, 445, 142,  78, 157, 476],
#            dtype='int64', length=979)
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# ...

# %%
movie_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movie_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movie_df.sort_values('duration', inplace= True)

# %%
movie_df
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %%
movie_df
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %%
movie_df.sort_values(['title', 'duration'])
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# ..           ...                    ...            ...        ...       ...
# 955          7.4       Zero Dark Thirty              R      Drama       157
# 677          7.7                 Zodiac              R      Crime       157
# 615          7.7             Zombieland              R     Comedy        88
# 526          7.8                   Zulu        UNRATED      Drama       138
# 864          7.5                  [Rec]              R     Horror        78
#
#                                            actors_list
# ...

# %%
movie_df['duration'] >= 200
# Out:
# 389    False
# 338    False
# 258    False
# 293    False
# 88     False
#        ...
# 445     True
# 142     True
# 78      True
# 157     True
# 476     True
# Name: duration, Length: 979, dtype: bool

# %%
movie_df[movie_df.duration >= 200]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
# 17           8.7                                  Seven Samurai
# 204          8.1                                        Ben-Hur
# 85           8.4                             Lawrence of Arabia
# 445          7.9                           The Ten Commandments
# 142          8.3              Lagaan: Once Upon a Time in India
# 78           8.4                    Once Upon a Time in America
# 157          8.2                             Gone with the Wind
# 476          7.8                                         Hamlet
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
len(movie_df)
# Out:
# 979

# %%
movie_df.loc[(movie_df.duration>=200) & (movie_df.genre == 'Crime')]
# Out:
#     star_rating                        title content_rating  genre  duration  \
# 2           9.1       The Godfather: Part II              R  Crime       200
# 78          8.4  Once Upon a Time in America              R  Crime       229
#
#                                           actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...

# %%
movie_df
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %%
movie_df.loc[0]
# Out:
# star_rating                                                     9.3
# title                                      The Shawshank Redemption
# content_rating                                                    R
# genre                                                         Crime
# duration                                                        142
# actors_list       [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# Name: 0, dtype: object
