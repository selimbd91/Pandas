# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
x = np.linspace(0, 100, 500)
s = 0.1
m = 40
y = np.exp(-(x - m)**2 / 2*s**2)*(1/np.sqrt(2*np.pi*s**2))
plt.plot(x, y)

# %%
plt.plot(x, y)
