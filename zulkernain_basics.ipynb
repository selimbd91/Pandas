# %%
import numpy as np
def fun():
    name = input('Enter your name =')
    print(f'welcome {name}')
    
def dun():
    grocery_list = ['rice', 'potato', 'banana']
    print(grocery_list.index('banana'))
    list_to_str = ' '.join(grocery_list)
    print(list_to_str)
    new_list = []
    
#     for i in range(5):
#         fruit = input('Enter the fruit name= ')
#         new_list.insert(0, fruit)
        
    num_list = []
    
    for i in range(10):
        num_list.append(np.random.randint(low= 1, high= 34))
    
    print(num_list)
    
    num = sorted(num_list, reverse= False)
    print(num)
        
    
    #print(new_list)
def grade(marks):
    
    if marks >= 85:
        print(f'you got A+')
    elif 80 <= marks <85:
        print('you got A')
    else:
        print('you fail:')
        
def gun():
    name = input('Enter the word >')
    name2 = list(reversed(name))
    name3 = ''.join(name2)
    if name == name3:
        print(f'{name} is palindrome')
        
    else:
        print(f'{name} is not palindrome')
        
def pam():
    dd = []
    gro_list = ['am', 'jam', 'water', 'kola', 'lau']
    kola_pani = [ 'sokla', 'dila', 'mon']
    dd += gro_list
    dd += kola_pani
    print(dd)
    
        
def amazing():
    
    with open('daily_star.txt', mode= 'r') as file:
        all_words= []
        for line in file.readlines():
            word = line.strip().split(' ')
            all_words += word
        print(all_words)
        print(len(all_words))
        
        unique_words = set(all_words)
        print(len(unique_words))
        
        with open('unique_word.txt', mode= 'w') as write_file:
            
            for word in unique_words:
                write_file.write(word)
                write_file.write('\n')
        
        
def main():
    #dun() 
#     grades = int(input('Enter your grade:'))
#     grade(grades)
    amazing()
    #pam()

    
    
if __name__ == '__main__':
    main()
# Out:
# ['The', 'Duke', 'and', 'Duchess', 'of', 'Sussex', 'jetted', 'off', 'to', 'Los', 'Angeles', 'from', 'Vancouver,', 'Canada,', 'at', 'the', 'end', 'of', 'March', 'as', 'soon', 'as', 'their', 'duties', 'to', 'Queen', 'finished.', '', 'Meghan', 'and', 'Harry', 'stepped', 'down', 'as', 'senior', 'members', 'of', 'the', 'Royal', 'Family', 'in', 'January,', 'and', 'the', 'Duke', 'had', 'months', 'of', 'deliberations', 'with', 'Prince', 'William,', 'Prince', 'Charles', 'and', 'the', 'Queen', 'before', 'an', 'arrangement', 'was', 'made.']
# 62
# 47
